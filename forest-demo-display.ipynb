# %%
import numpy as np
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.11</span>
#         </div>

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Load data</span>

# %%
pixiedust.sampleData()
# Out:
# <table class="table table-hover pd_save" style="font-size:small">
#   <thead>
#     <tr>
#       <th align="center" valign="middle">Id</th>
#       <th>Name</th>
#       <th>Topic</th>
#       <th>Publisher</th>
#     </tr>
#   </thead>
#   <tbody>
#
#
#     <tr>
#         <td>1</td>
#         <td>Car performance data</td>
#         <td>Transportation</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>2</td>
#         <td>Sample retail sales transactions, January 2009</td>
#         <td>Economy & Business</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>3</td>
#         <td>Total population by country</td>
#         <td>Society</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>4</td>
#         <td>GoSales Transactions for Naive Bayes Model</td>
#         <td>Leisure</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>5</td>
# ...

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Load data into a Spark DataFrame</span>

# %%
df = pixiedust.sampleData(6)
# Out:
# ...
# Downloaded 999888 bytes
# Creating pandas DataFrame for 'Million dollar home sales in Massachusetts, USA Feb 2017 through Jan 2018'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'Million dollar home sales in Massachusetts, USA Feb 2017 through Jan 2018'

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Load data from url</span>

# %%
df = pixiedust.sampleData(
    "https://openobjectstore.mybluemix.net/misc/milliondollarhomes.csv")
# Out:
# ...
# Downloaded 102051 bytes
# Creating pandas DataFrame for 'https://openobjectstore.mybluemix.net/misc/milliondollarhomes.csv'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'https://openobjectstore.mybluemix.net/misc/milliondollarhomes.csv'

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Load data in a pandas DataFrame</span>

# %%
df = pixiedust.sampleData(6, forcePandas = True)
# Out:
# Creating pandas DataFrame for 'Million dollar home sales in Massachusetts, USA Feb 2017 through Jan 2018'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'Million dollar home sales in Massachusetts, USA Feb 2017 through Jan 2018'

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Display CO$_2$ data as a table</span>

# %%
co2 = pixiedust.sampleData(
        "file:///Users/margriet/projects/visualisation-forest/data/co2_weekly_mlo.csv",
        forcePandas = True)
# Out:
# ...
# Downloaded 115377 bytes
# Creating pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/co2_weekly_mlo.csv'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/co2_weekly_mlo.csv'

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Filter rows > 400 ppm</span>

# %%
display(co2)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure120d59a5" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
# ...

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Display CO$_2$ data as a line chart</span>
#
# * matplotlib, bokeh and brunel
# * cluster by month
# * subplots
# * brunel dynamic filter

# %%
co2 = co2.replace(-999.99, np.nan)
display(co2)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure97c26d1f" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
# ...

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Display forest data as a bar chart</span>

# %%
forest = pixiedust.sampleData(
        "file:///Users/margriet/projects/visualisation-forest/data/forest_map.csv",
        forcePandas = True)

forest['forest2015'] = forest['2015']
# Out:
# ...
# Downloaded 55283 bytes
# Creating pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/forest_map.csv'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/forest_map.csv'

# %%
forest.head()
# Out:
#    CountryName CountryCode                 IndicatorName   IndicatorCode  \
# 0        Aruba         ABW  Forest area (% of land area)  AG.LND.FRST.ZS
# 1  Afghanistan         AFG  Forest area (% of land area)  AG.LND.FRST.ZS
# 2       Angola         AGO  Forest area (% of land area)  AG.LND.FRST.ZS
# 3      Albania         ALB  Forest area (% of land area)  AG.LND.FRST.ZS
# 4      Andorra         AND  Forest area (% of land area)  AG.LND.FRST.ZS
#
#     1990   1991   1992   1993   1994   1995     ...       2007   2008   2009  \
# 0   2.33   2.33   2.33   2.33   2.33   2.33     ...       2.33   2.33   2.33
# 1   2.07   2.07   2.07   2.07   2.07   2.07     ...       2.07   2.07   2.07
# 2  48.91  48.81  48.71  48.61  48.51  48.41     ...      47.21  47.11  47.01
# 3  28.79  28.72  28.65  28.57  28.50  28.43     ...      28.47  28.42  28.38
# 4  34.04  34.04  34.04  34.04  34.04  34.04     ...      34.04  34.04  34.04
#
#     2010   2011   2012   2013   2014   2015  forest2015
# ...

# %% [markdown]
# * filter data `2015` > 85%
# * bar chart `CountryCode` - `2015`
# * renderers
# * interactive
# * sort values descending

# %%
display(forest)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><script class="pd_save is-viewer-good">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-58daf11a")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#     (function() {
#   var fn = function() {
#     Bokeh.safely(function() {
#       (function(root) {
#         function embed_document(root) {
# ...

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Display forest data as a scatter plot</span>

# %%
display(forest)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigurebfc5ddc0" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save"></center>
#
#
#
#         </div>

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Maps!</span>

# %% [markdown]
# https://data.worldbank.org/indicator/AG.LND.FRST.ZS

# %%
display(forest)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">More Maps!</span>

# %%
sites = pixiedust.sampleData(
        "file:///Users/margriet/projects/visualisation-forest/data/siteslatlon.csv",
        forcePandas = True)
sites.head()
# Out:
# ...
# Downloaded 3667 bytes
# Creating pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/siteslatlon.csv'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/siteslatlon.csv'
#      Site   n      a     b    r2  Latitude  Longitude
# 0  AU-Fog  15  58.97 -1.91  0.20    -12.54     131.31
# 1  AU-How  33  -7.39 -0.69  0.32    -12.49     131.15
# 2  AU-Tum   7 -37.48 -0.35  0.72    -35.66     148.15
# 3  BE-Bra  27  -1.18 -0.43  0.59     51.31       4.52
# 4  BE-Lon  16 -26.47  0.57  0.18     50.55       4.74

# %%
display(sites)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigureb3717de6" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <script>
#   window.iframeLoaded = window.iframeLoaded || function(iframe) {
#     try {
#       iframe.contentWindow.pdMessageListeners = [];
#       iframe.contentWindow["addPDMessageListener"] = function(listener){
#         iframe.contentWindow.pdMessageListeners.push(listener);
#       }
#       iframe.contentWindow.addEventListener("message", function(event){
#         iframe.contentWindow.pdMessageListeners.forEach(function(listener){
#           listener(event);
#         });
# ...
