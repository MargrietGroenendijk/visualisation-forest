# %%
import numpy as np
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.11</span>
#         </div>

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Load data</span>

# %%
co2 = pixiedust.sampleData(
        "file:///Users/margriet/projects/visualisation-forest/data/co2_weekly_mlo.csv",
        forcePandas = True)
# Out:
# Creating pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/co2_weekly_mlo.csv'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/co2_weekly_mlo.csv'

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Display data as a table</span>
#
# * Filter rows > 400 ppm
# * Show only 10 rows

# %%
display(co2)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure50795a1b" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
# ...

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Display data as a line chart</span>
#
# * matplotlib, bokeh and brunel
# * cluster by month
# * subplots
# * brunel dynamic filter

# %%
co2 = co2.replace(-999.99, np.nan)
display(co2)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>

# %%
forest = pixiedust.sampleData(
        "file:///Users/margriet/projects/visualisation-forest/data/forest_map.csv",
        forcePandas = True)

forest['forest2015'] = forest['2015']
# Out:
# Creating pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/forest_map.csv'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/forest_map.csv'

# %%
forest.head()
# Out:
#    CountryName CountryCode                 IndicatorName   IndicatorCode  \
# 0        Aruba         ABW  Forest area (% of land area)  AG.LND.FRST.ZS
# 1  Afghanistan         AFG  Forest area (% of land area)  AG.LND.FRST.ZS
# 2       Angola         AGO  Forest area (% of land area)  AG.LND.FRST.ZS
# 3      Albania         ALB  Forest area (% of land area)  AG.LND.FRST.ZS
# 4      Andorra         AND  Forest area (% of land area)  AG.LND.FRST.ZS
#
#         1990       1991       1992       1993       1994       1995  \
# 0   2.333333   2.333333   2.333333   2.333333   2.333333   2.333333
# 1   2.067825   2.067825   2.067825   2.067825   2.067825   2.067825
# 2  48.909922  48.809818  48.709714  48.609609  48.509505  48.409401
# 3  28.788321  28.717153  28.645985  28.574818  28.503650  28.432482
# 4  34.042553  34.042553  34.042553  34.042553  34.042553  34.042553
#
#       ...           2007       2008       2009       2010       2011  \
# ...

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Display data as bar chart</span>
#
# * filter data
# * bar chart country code - forest2015
# * renderers
# * interactive
# * sort descending

# %%
display(forest)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#
#         <div id="chartFigure91ff7eab" class="pd_save" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-91ff7eab")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# ...

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Display data as a scatter plot</span>

# %%
display(forest)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save is-viewer-good">

# %% [markdown]
# <span style="color: #A51B73; font-size: 1.5em; font-weight:bold">Maps!</span>

# %%
#https://www.atmos.illinois.edu/~meiyapp2/datasets.htm
#https://data.worldbank.org/indicator/AG.LND.FRST.ZS

# %%
display(forest)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>

# %%
weather = pixiedust.sampleData(
        "file:///Users/margriet/projects/visualisation-forest/data/weather_uk3.csv",
        forcePandas = True)
weather.head()
# Out:
# ...
# Downloaded 2044 bytes
# Creating pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/weather_uk3.csv'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'file:///Users/margriet/projects/visualisation-forest/data/weather_uk3.csv'
#    Unnamed: 0  chance of rain  temperature  humidity  wind speed  \
# 0           0              20           14        93          23
# 1           0              18           11        94          14
# 2           0              17           12        92          16
# 3           0              40           13       100          24
# 4           0              40           11        96          20
#
#                         date        city        lat       lon
# 0  2017-11-20 19:00:00+00:00      Dublin  53.342686 -6.267118
# 1  2017-11-20 19:00:00+00:00      Exeter  50.718400 -3.533900
# 2  2017-11-20 19:00:00+00:00       Truro  50.263200 -5.051000
# ...

# %%
display(weather)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigureb319fd04" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <script>
#   window.iframeLoaded = window.iframeLoaded || function(iframe) {
#     try {
#       iframe.contentWindow.pdMessageListeners = [];
#       iframe.contentWindow["addPDMessageListener"] = function(listener){
#         iframe.contentWindow.pdMessageListeners.push(listener);
#       }
#       iframe.contentWindow.addEventListener("message", function(event){
#         iframe.contentWindow.pdMessageListeners.forEach(function(listener){
#           listener(event);
#         });
# ...
